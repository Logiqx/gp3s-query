# %% [markdown]
# # Check Events
#
# Check event rankings from GP3S.
#
# Copyright 2022 Michael George (AKA Logiqx).
#
# This file is part of GP3S Query and is distributed under the terms of the GNU General Public License.
#
# GP3S Query is free software: you can redistribute it and/or modify it under the terms of the GNU General Public License as published by the Free Software Foundation, either version 3 of the License, or (at your option) any later version.
#
# GP3S Query is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the GNU General Public License for more details.
#
# You should have received a copy of the GNU General Public License along with GP3S Query. If not, see https://www.gnu.org/licenses/.

# %% [markdown]
# ## Import Common Modules

# %%
import os
import sys

import json

# %% [markdown]
# ## Event IDs
#
# Obtained from gps-speedsurfing.com

# %%
events = {}

users = {}

# %% [markdown]
# ## Load Events

# %%
def getUid(sessionUrl):
    """Get user ID from session URL"""

    for param in sessionUrl.split('&'):
        if '=' in param:
            parts = param.split('=')
            if parts[0] == 'uid':
                uid = int(parts[1])
            
    return uid

# %%
def loadEventRankings(eventDir):
    """Load event rankings"""
    
    rankings = {}

    for rankingsFile in sorted(os.listdir(eventDir)):
        filename = os.path.join(eventDir, rankingsFile)
        with open(filename) as f:
            speedType = os.path.splitext(rankingsFile)[0]
            rankings[speedType] = json.load(f)

    return rankings

# %%
def parseEventRankings(rankings, verbose=False):
    """Parse event rankings"""

    bests = {}
    duplicates = {}
    
    for speedType, rows in rankings.items():
        if speedType not in bests:
            bests[speedType] = {}

        if speedType not in duplicates:
            duplicates[speedType] = {}
            
        for row in rows:
            uid = getUid(row['sessionurl'])
            
            if uid not in users:
                users[uid] = row['username']

            if uid in bests[speedType]:
                duplicates[speedType][uid] = row['speed']

            bests[speedType][uid] = row['speed']

    return bests, duplicates

# %%
def loadEventSessions(eventId):
    """Load event sessions"""
    
    sessions = {}

    filename = os.path.join(projdir, 'cache', 'EventSessions', str(eventId) + '.json')
    with open(filename) as f:
        sessions = json.load(f)

    for session in sessions:
        if eventId not in events:
            events[eventId] = session['eventname']
            break

    return sessions

# %%
def parseEventSessions(sessions):
    """Parse event sessions"""

    bests = {}
    
    for session in sessions:
        uid = getUid(session['sessionurl'])
                
        if uid not in users:
            users[uid] = session['username']

        for speedType in session:
            if speedType.startswith('speed_'):
                if speedType not in bests:
                    bests[speedType] = {}

                if uid not in bests[speedType]:
                    bests[speedType][uid] = 0
                    
                if session[speedType] > bests[speedType][uid]:
                    bests[speedType][uid] = session[speedType]

    return bests

# %%
def compareBests(eventId, rankingBests, rankingDuplicates, sessionBests, verbose=False):
    """Compare rankings against sessions"""

    rebuild = {}

    for speedType, uids in rankingDuplicates.items():
        for uid, speed in uids.items():
            if verbose:
                print('{} ({}) duplicate {} - {:.2f}'.format(users[uid], uid, speedType, speed))
            if uid not in rebuild:
                rebuild[uid] = set()
            rebuild[uid].add(speedType)
                
    for speedType, uids in rankingBests.items():
        if speedType not in sessionBests:
            if verbose:
                print('Warning: {} not in EventSessions'.format(speedType))
        else:
            for uid, speed in uids.items():
                if uid not in sessionBests[speedType]:
                    if verbose:
                        print('{} ({}) {} not in EventSessions'.format(users[uid], uid, speedType))
                    if uid not in rebuild:
                        rebuild[uid] = set()
                    rebuild[uid].add(speedType)

    for speedType, uids in sessionBests.items():
        if speedType not in rankingBests:
            if verbose:
                print('Warning: {} not in EventRankings'.format(speedType))
        else:
            for uid, speed in uids.items():
                if uid not in rankingBests[speedType]:
                    if speed > 0:
                        if verbose:
                            print('{} ({}) {} not in EventRankings - {:.2f} session'.format(
                                users[uid], uid, speedType, speed))
                        if uid not in rebuild:
                            rebuild[uid] = set()
                        rebuild[uid].add(speedType)
                else:
                    if rankingBests[speedType][uid] != speed:
                        if verbose:
                            print('{} ({}) mismatch for {} - {:.2f} ranking vs {:.2f} session'.format(
                                users[uid], uid, speedType, rankingBests[speedType][uid] / 1.852, speed / 1.852))
                        if uid not in rebuild:
                            rebuild[uid] = set()
                        rebuild[uid].add(speedType)

    if verbose and rebuild:
        print()

    if rebuild:
        print('{} / {} users need a rebuild in {} ({}):'.format(len(rebuild), len(users), events[eventId], eventId))
        for uid in rebuild:
            print('{} ({}) - {}'.format(users[uid], uid, ', '.join(rebuild[uid])))
    else:
        print('No users need a rebuild in {} ({})'.format(events[eventId], eventId))

    print()

# %%
if __name__ == '__main__':
    projdir = os.path.realpath(os.path.join(sys.path[0], '..'))
    verbose = False

    basedir = os.path.join(projdir, 'cache', 'EventRankings')
    
    eventIds = [int(dirname) for dirname in os.listdir(basedir)]
    
    for eventId in eventIds:
        if verbose:
            print('Checking event {}'.format(eventId))

        eventDir = os.path.join(basedir, str(eventId))
        
        rankings = loadEventRankings(eventDir)
        rankingBests, rankingDuplicates = parseEventRankings(rankings, verbose=verbose)

        try:
            sessions = loadEventSessions(eventId)
            sessionBests = parseEventSessions(sessions)

            compareBests(eventId, rankingBests, rankingDuplicates, sessionBests, verbose=verbose)
            
        except FileNotFoundError:
            # I have intentionally cached the event rankings (but not sessions) for the British Foil Speed Challenge 2022
            pass
        
    print('All done!')
# Out:
# No users need a rebuild in 2022 FFF SPEED CHALLENGE (727)
#
# 3 / 22 users need a rebuild in 2022 Funsport Makkum GPS Speed Challenge (740):
# Paul Salomons (3078) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Rob de Jong (4307) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
# Jan Hendrik de Bruin (2574) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
#
# 1 / 29 users need a rebuild in 2022 Irish Speed Masters (717):
# Gildas Bechet (3671) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
#
# No users need a rebuild in Surf like a dude Zuidlaardermeer Speed Challenge 2022 (730)
#
# No users need a rebuild in Norwegian speedmaster - 2022 (719)
#
# 6 / 86 users need a rebuild in SSS Go big or go Home 2021-2022 (715):
# Hans Prins (5376) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Sven Hulst (23299) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100
# Ingolf van Oostveen (3874) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# René Bijmolt (21711) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
# Jan Joustra (23396) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100
# Alwin Visker (15697) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
#
# No users need a rebuild in Wurster ONE hour (731)
#
# No users need a rebuild in Lysakerfjorden 2022 (722)
#
# 1 / 118 users need a rebuild in 2022 Spanish Speed Challenge (737):
# eduardo de llano (25460) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
#
# No users need a rebuild in WSCA Westeinder Speedking 2022 (726)
#
# 1 / 151 users need a rebuild in 2022 DBO Speed Challenge (732):
# Andrei Josephsen (25722) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
#
# 3 / 156 users need a rebuild in Surf like a dude Zuidlaardermeer speed challenge 2021 (692):
# Eric Kamminga (3309) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Tim Heeringa (23642) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Andre Poelman (24607) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
#
# 46 / 452 users need a rebuild in 2022 Dunkerbeck Speed Challenge “The Summer Edition” (748):
# Kai Kaufmann (16746) - speed_10sec, speed_500, speed_avg, speed_250, speed_100, speed_mile
# Christopher Tyack (22404) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Tor Kjell Grytnes  (22817) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Konstantinos Palogos (23998) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Jorgen Dyblie (23206) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Torbjörn Hellström (23334) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Kristian Grytnes (23632) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
# Will Trossell (2911) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Sven Hulst (23299) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Pavlos Kapsianis (24816) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Jorrit Bonnema (22388) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Markus Lindman (5423) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100
# Ingolf van Oostveen (3874) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Bert Bodde (20514) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Alwin Visker (15697) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Mandy van de Hoef (23463) - speed_10sec, speed_2sec, speed_avg, speed_250, speed_100
# Ove Jansson (4642) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Alberto Marugan (25183) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100
# Chris Platt (25193) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# René Bijmolt (21711) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
# Jüri Kaldoja (4497) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100, speed_mile
# Fons van den Hove (24311) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Phil Noden (2708) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100, speed_mile
# Olsson Orjan (18230) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Frank Heinen (82) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Tore Hvideberg (25617) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Nicole Skodda (6348) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
# Lianne Hofstee (26179) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
# Dylan de Jong (53) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
# Aart Veerman (3607) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# René van der Weijde (5123) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Hans Prins (5376) - speed_100, speed_2sec, speed_avg, speed_mile
# Uwe Eßer (6331) - speed_10sec, speed_hour, speed_2sec, speed_avg, speed_250, speed_100
# Magnus Bengtsson (2046) - speed_10sec, speed_500, speed_hour, speed_avg, speed_250, speed_100
# Anders Bjorkqvist (2558) - speed_hour, speed_avg, speed_mile
# Arne Noer (24403) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Edwin Buruma (23550) - speed_10sec, speed_hour, speed_2sec, speed_avg, speed_250, speed_100
# Peter L Rasmussen (26059) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Kirsten Baas (22540) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100
# Robert Baas (19409) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100, speed_mile
# Thomas Moldenhauer (24163) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Hans Kreisel (2042) - speed_10sec, speed_500, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Regis Lesieur (22394) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100
# Saar Schuling  (25189) - speed_hour, speed_mile
# Kootstra Tom (24490) - speed_hour
# Mateusz Kasprzak (25524) - speed_hour
#
# No users need a rebuild in World Speed Tour - GPS POS 2022  (734)
#
# No users need a rebuild in 2021 Red Bull Bora Challenge (712)
#
# 1 / 484 users need a rebuild in 2022 Gps Kraaij Challenge (721):
# Erwin Rovers (5095) - speed_2sec
#
# No users need a rebuild in 2022  (733)
#
# 1 / 512 users need a rebuild in Singlis-Speedchallenge 2022 (725):
# Arnd Gottschalk (26098) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
#
# 8 / 517 users need a rebuild in Schildmeer Speed Challenge 2021-2022 (704):
# Edwin Buruma (23550) - speed_10sec, speed_2sec, speed_avg, speed_250, speed_100
# Ingolf van Oostveen (3874) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Hans Prins (5376) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100
# Saar Schuling  (25189) - speed_10sec, speed_2sec, speed_avg, speed_250, speed_100
# Alwin Visker (15697) - speed_250
# Frans Werkman (5650) - speed_500, speed_hour, speed_mile
# Bert Bodde (20514) - speed_hour, speed_mile
# Sven Hulst (23299) - speed_hour, speed_mile
#
# No users need a rebuild in 2022 Estonian Speed King (739)
#
# No users need a rebuild in 2022 Odyssey of Speed (736)
#
# 5 / 589 users need a rebuild in BritishSpeedChallenge2022 (710):
# Norman Petty (2307) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100
# George Fulton (16978) - speed_10sec, speed_500, speed_2sec, speed_avg, speed_250, speed_100
# Garry Connell (18265) - speed_500, speed_2sec, speed_avg, speed_mile
# Mark Ingram (5835) - speed_10sec, speed_500, speed_2sec, speed_hour, speed_avg, speed_250, speed_100, speed_mile
# Steve Thompson (3592) - speed_500, speed_hour, speed_mile
#
# All done!
